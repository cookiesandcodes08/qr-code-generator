# %%
# !pip install qrcode
# !pip install pillow
# Out:
# Requirement already satisfied: qrcode in c:\users\shrey\new folder\lib\site-packages (8.2)
# Requirement already satisfied: colorama in c:\users\shrey\new folder\lib\site-packages (from qrcode) (0.4.6)
# Requirement already satisfied: pillow in c:\users\shrey\new folder\lib\site-packages (12.0.0)

# %%
import streamlit as st
import qrcode

st.title("QR Code Generator")

data = st.text_input("Enter a URL or Text")

if st.button("Generate QR Code"):
    if data:
        img = qrcode.make(data)

        img.save("QRcode.png")   # Save first

        st.image("QRcode.png")   # Display the saved image

        st.success("QR Code Generated Successfully!")

    else:
        st.warning("Please enter some text first!")
# Out:
# 2026-07-13 10:28:42.253 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.270
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\shrey\New folder\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-13 10:28:44.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.289 Session state does not function when running a script without `streamlit run`
# 2026-07-13 10:28:44.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-13 10:28:44.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
